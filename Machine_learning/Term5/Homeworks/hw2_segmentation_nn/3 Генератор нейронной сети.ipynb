# %% [markdown]
# 1) Используя циклы сделайте генерацию текста функции, которая отвечает за создание архитектуры нейросети.
#
# 2) Сделайте автоподсчет количества пикселей из расчета размерности внутреннего пространства с картой признаков. При условии, что в каждом блоки идет уменьшение изображения в 2 раза.

# %%
#
