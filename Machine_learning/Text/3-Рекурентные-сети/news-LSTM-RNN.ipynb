# %% [markdown]
# # Классификация произведений писателей с помощью LSTM, SimpleRNN

# %%
from google.colab import files # Для работы с файлами 
import numpy as np # Для работы с данными 
import matplotlib.pyplot as plt # Для вывода графиков
import os # Для работы с файлами
# %matplotlib inline

from tensorflow.keras import utils # Для работы с категориальными данными
from tensorflow.keras.models import Sequential # Полносвязная модель
from tensorflow.keras.layers import Dense, Dropout, SpatialDropout1D, BatchNormalization, Flatten, Activation, Embedding, SimpleRNN, LSTM # Слои для сети
from tensorflow.keras.preprocessing.text import Tokenizer # Методы для работы с текстами
from tensorflow.keras.preprocessing.sequence import pad_sequences # Метод для работы с последовательностями

from google.colab import drive # Для работы с Google Drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Удаляем директорию с распакованными данными (если есть)
# !rm -rf /content/news

# %%
# !unzip -q '/content/drive/MyDrive/Colab Notebooks/Machine_learning/Datasets/news.zip' -d /content/

# %%
# Функция для загрузки файла
def loadText(fileName):
  f = open(fileName, 'r') # Открываем файл в режиме чтения
  text = f.read()         # Читаем текст
  text = text.replace("\n", " ") # Заменяем переносы строк на пробелы
  text = text.replace("\r", " ") # Заменяем переносы строк на пробелы
  text = text.replace("\t", " ") # Заменяем табуляции на пробелы
  f.close()
  
  return text

labels = ["Политика", "Спорт", "Технологии"] # Классифицируемые новости
labelsNum = len(labels) # Количество классифицируемых групп

# %%
# Загружаем тексты из обучающей и тренировочной выборок

trainText = [] # Обучающие тексты
testText = []  # Тестовые тексты

fileList = os.listdir('news/') # Получаем список всех файлов
for label in labels:
  for file in fileList:
    if label in file: # Проверяем, содержит ли файл j в названии имя класса i
      if 'Обучающая' in file: # Если в имени найденного класса есть строка "Обучающая" 
        trainText.append(loadText('news/' + file)) #добавляем в обучающую выборку
        print(file, 'добавлен в обучающую выборку')
      if 'Тестовая' in file: # Если в имени найденного класса есть строка "Тестовая"
        testText.append(loadText('news/' + file)) # Добавляем в обучающую выборку
        print(file, 'добавлен в тестовую выборку')
# Out:
# Политика Обучающая.txt добавлен в обучающую выборку
# Политика Тестовая.txt добавлен в тестовую выборку
# Спорт Обучающая.txt добавлен в обучающую выборку
# Спорт Тестовая.txt добавлен в тестовую выборку
# Технологии Обучающая.txt добавлен в обучающую выборку
# Технологии Тестовая.txt добавлен в тестовую выборку

# %%
print("Количество загруженных обучающих текстов:", len(trainText))
print("Количество загруженных тестовых текстов:", len(testText))
# Out:
# Количество загруженных обучающих текстов: 3
# Количество загруженных тестовых текстов: 3

# %% [markdown]
# Токенизируем тексты

# %%
numWords = 20000 # Количество слов/индексов, которое мы будем учитывать при обучении

# Tokenizer - встроенная в Keras функция для разбиения текста и превращения
# в слов в числовые значения с учётом частотности

# num_words - максимальное количество слов/индексов, учитываемое при составлении словаря
# filters - список ненужных символов, которые будут удалены из текстов
# lower - приведение слов к нижнему регистру
# split - разделитель между словами
# oov_token - на какое слово будем заменять слова, которые выше по частоте, чем numWords
# char_level - разбитие по буквам или по словам

tokenizer = Tokenizer(num_words=numWords,
                      filters='!"#$%&()*+,-–—./…:;<=>?@[\\]^_`{|}~«»\t\n\xa0\ufeff',
                      lower=True,
                      split=' ',
                      oov_token='unknown',
                      char_level=False)

tokenizer.fit_on_texts(trainText) # Cоберем словарь частотности
items = list(tokenizer.word_index.items()) # Получаем индексы слов

# %%
print("Самые часто встречающиеся слова:")
print(items[:10])
print()
print("Самые редко встречающиеся слова:")
print(items[-10:])
print()
print("Размер словаря:", len(items))
# Out:
# Самые часто встречающиеся слова:
# [('unknown', 1), ('в', 2), ('и', 3), ('на', 4), ('с', 5), ('не', 6), ('что', 7), ('по', 8), ('за', 9), ('для', 10)]
#
# Самые редко встречающиеся слова:
# [('ming', 69837), ('chi', 69838), ('kuo', 69839), ('исчезут', 69840), ('начальную', 69841), ('воссоздали', 69842), ('sanktperkele', 69843), ('встроенного', 69844), ('достоверно', 69845), ('подошёл', 69846)]
#
# Размер словаря: 69846

# %%
# # Тестирование словаря
# inputWord = input("Введите слово: ")
# print("Индекс слова ",inputWord, ": ", tokenizer.word_index[inputWord])

# %%
# Преобразование текста в последовательность индексов согласно частотному словарю
trainWordIndexes = tokenizer.texts_to_sequences(trainText)
testWordIndexes = tokenizer.texts_to_sequences(testText)

# %%
# Проверка преобразования
print("Фрагмент обучающего текста:")
print("В виде оригинального текста:              ", trainText[2][:23])
print("Он же в виде последовательности индексов: ", trainWordIndexes[0][:5], '\n')
# Out:
# Фрагмент обучающего текста:
# В виде оригинального текста:                Софт и игры Обзор Part
# Он же в виде последовательности индексов:  [143, 49, 99, 164, 136]

# %%
print("Статистика по обучающим текстам:")

symbolsTrainText = 0 # Для подсчета символов в обучающих текстах
wordsTrainText = 0 # Для подсчета слов в обучающих текстах

for i in range(labelsNum): # Проход по всем классам
  print(labels[i], " "*(10-len(labels[i])), len(trainText[i]), "символов, ", len(trainWordIndexes[i]), "слов")
  symbolsTrainText += len(trainText[i]) # Подсчёт символов
  wordsTrainText += len(trainWordIndexes[i]) # Подсчёт слов 

print('----')
print("В сумме ", symbolsTrainText, " символов, ", wordsTrainText, " слов \n")
print()
print("Статистика по тестовым текстам:")

symbolsTestText = 0 # Для подсчета символов в тестовых текстах
wordsTestText = 0 # Для подсчета слов в тестовых текстах

for i in range(labelsNum): #Проход по всем классам
  print(labels[i], ' '*(10-len(labels[i])), len(testText[i]), "символов, ", len(testWordIndexes[i]), "слов")
  symbolsTestText += len(testText[i]) # Подсчёт символов
  wordsTestText += len(testWordIndexes[i]) # Подсчёт слов 
print('----')
print("В сумме ", symbolsTestText, " символов, ", wordsTestText, " слов")
# Out:
# Статистика по обучающим текстам:
# Политика    1744978 символов,  238065 слов
# Спорт       1808908 символов,  262022 слов
# Технологии  1779783 символов,  253146 слов
# ----
# В сумме  5333669  символов,  753233  слов
#
#
# Статистика по тестовым текстам:
# Политика    197551 символов,  26851 слов
# Спорт       169031 символов,  24435 слов
# Технологии  186296 символов,  26250 слов
# ----
# В сумме  552878  символов,  77536  слов

# %% [markdown]
# Создаем xTrain и yTrain

# %%
# Формирование обучающей выборки по листу индексов слов
# путем разделения на короткие векторы
# wordIndexes - массив индексов
# xLen - размер окна
# step - шаг окна
def getSetFromIndexes(wordIndexes, xLen, step):
  xText = []
  wordsLen = len(wordIndexes) # Считаем количество слов
  index = 0 # Задаем начальный индекс 

  while (index + xLen <= wordsLen): # Идём по всей длине вектора индексов
    xText.append(wordIndexes[index:index+xLen]) # "Откусываем" векторы длины xLen
    index += step # Смещаеммся вперёд на step
    
  return xText


# Формирование обучающей и проверочной выборки для каждого класса
# wordIndexes - массив индексов
# xLen - размер окна
# step - шаг окна
def createSetsMultiClasses(wordIndexes, xLen, step): # Функция принимает последовательность индексов, размер окна, шаг окна
  nClasses = len(wordIndexes) # Количество классов
  classesXSamples = []        # Здесь будет список размером "кол-во классов*кол-во окон в тексте*длину окна (например, 6 по 1341*1000)"
  for wI in wordIndexes:      # Для каждого текста выборки из последовательности индексов
    classesXSamples.append(getSetFromIndexes(wI, xLen, step))

  # Формируем один общий xSamples
  xSamples = []
  ySamples = []
  
  for t in range(nClasses):
    xT = classesXSamples[t]
    for i in range(len(xT)): # Перебираем каждое окно определенного класса
      xSamples.append(xT[i]) # Добавляем в общий список выборки
      ySamples.append(utils.to_categorical(t, nClasses)) # Добавляем соответствующий вектор класса

  xSamples = np.array(xSamples)
  ySamples = np.array(ySamples)

  
  return (xSamples, ySamples)

# %%
# Установка базовых параметров для анализа текстов
xLen = 300 # Размер окна (количество слов в векторе)
step = 300 # Шаг разбиения текста на векторы

# Новостей больших нет, поэтому шаг и рамка = 300

# %%
# Формируем обучающую и тестовую выборку
xTrainId, yTrain = createSetsMultiClasses(trainWordIndexes, xLen, step)
xTestId, yTest = createSetsMultiClasses(testWordIndexes, xLen, xLen)
print("Размерности тренировочного набора")
print(xTrainId.shape)
print(yTrain.shape)
print()
print("Размерности тестового набора")
print(xTestId.shape)
print(yTest.shape)
# Out:
# Размерности тренировочного набора
# (2509, 300)
# (2509, 3)
#
# Размерности тестового набора
# (257, 300)
# (257, 3)

# %%
print(xTrainId[0])
# Out:
# [  143    49    99   164   136    24   162   145   102     2  6658   106
#    878    81  3074  2061     5   390    99  1751   666     2  1266  3074
#    440     5   390   342  1027   747  5887  1785   106  1232     1     2
#   2205     4  1644     2  1926   477  1362     4  2005     4 10642    20
#     20    43    90  1751  6659     2  1266  3074   440     5   390   147
#  13353  4641    11  2767     6     1     1     1     5 15446     4   706
#    147  1563     1     1  2688     8     1   350    29    65    62  2311
#     28    10    95    61    43    54    82     1     4   523   120   782
#    266    25   150   178  1267  4240  2557     8  2897  1785     3     1
#  10643  5596   234 13354  2108     5 18063     7    49 13355  1006   924
#      4   706    11  2767     4   817   274 18064 10644    44    46  2612
#   6660     3     1  1051  2767     6 18065   485   612  8187     7    49
#      6 18066  1006    19    65   620  1588     2   401     5     1  4439
#      5   306   221    49     5    20   108  9621  2842  5597   924     4
#    706     2 18067   148   878     7  8188   925  2160     5 13356 13357
#   9622     2 18068  6248   926     2  1786  4642     7     2  1973     5
#   3389     1   925  5888     1   924     4   170   140    26     1    51
#   3075    89   924     1     4   706     2  1974    30  1854 13358   412
#      2  4077   925   350     2   486 11865   965   392   106     2   743
#   3511   540  1787  1249    22     1  3076   956   320     3     1   320
#    925   350     2   916    44    46   717  1676  1854 13359     7   120
#    540   209  8189     3   452   707     6 13360  9623     2   486  6249
#   2898   143    49    99   164   136    24   162   145   102 15447 11866
#   2689    12  5889   445     5  5091   683    24    21   818    14    49
#    469  6250   667 11867     5   966  7587    24     2  2161   289     3]

# %%
# Не преобразуем в Bag Of Words
# xTrain  = tokenizer.sequences_to_matrix(xTrainId.tolist())
# xTest  = tokenizer.sequences_to_matrix(xTestId.tolist())

xTrain = xTrainId
xTest  = xTestId

print("Размерность обучайющей выборки")
print(xTrain.shape)
print(yTrain.shape)

print()

print("Размерность тестовой выборки")
print(xTest.shape)
print(yTest.shape)
# Out:
# Размерность обучайющей выборки
# (2509, 300)
# (2509, 3)
#
# Размерность тестовой выборки
# (257, 300)
# (257, 3)

# %% [markdown]
# Нейросеть для классификации текстов на базе RNN

# %%
modelRNN = Sequential()

modelRNN.add(Embedding(numWords, 5, input_length=xLen))
modelRNN.add(SpatialDropout1D(0.2))
modelRNN.add(BatchNormalization())

modelRNN.add(SimpleRNN(16, dropout=0.2, recurrent_dropout=0.2, activation="relu"))
modelRNN.add(Dense(3, activation='softmax'))

modelRNN.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

modelRNN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 300, 5)            100000
#
#  spatial_dropout1d (SpatialD  (None, 300, 5)           0
#  ropout1D)
#
#  batch_normalization (BatchN  (None, 300, 5)           20
#  ormalization)
#
#  simple_rnn (SimpleRNN)      (None, 16)                352
#
#  dense (Dense)               (None, 3)                 51
#
# =================================================================
# Total params: 100,423
# Trainable params: 100,413
# Non-trainable params: 10
# _________________________________________________________________

# %%
# Обучаем сеть
historyRNN = modelRNN.fit(xTrain, 
                          yTrain, 
                          epochs=20,
                          batch_size=128,
                          validation_split=0.2)
# Out:
# Epoch 1/20
# 16/16 [==============================] - 11s 503ms/step - loss: 1.1653 - accuracy: 0.3787 - val_loss: 1.1360 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 16/16 [==============================] - 8s 502ms/step - loss: 1.0823 - accuracy: 0.4170 - val_loss: 1.1762 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 16/16 [==============================] - 8s 522ms/step - loss: 1.0397 - accuracy: 0.4669 - val_loss: 1.2115 - val_accuracy: 0.0000e+00
# Epoch 4/20
# 16/16 [==============================] - 8s 497ms/step - loss: 0.9895 - accuracy: 0.4963 - val_loss: 1.2383 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 16/16 [==============================] - 8s 519ms/step - loss: 0.9516 - accuracy: 0.5286 - val_loss: 1.2663 - val_accuracy: 0.0000e+00
# Epoch 6/20
# 16/16 [==============================] - 8s 477ms/step - loss: 0.9170 - accuracy: 0.5720 - val_loss: 1.2928 - val_accuracy: 0.0000e+00
# Epoch 7/20
# 16/16 [==============================] - 8s 495ms/step - loss: 0.8903 - accuracy: 0.5790 - val_loss: 1.3109 - val_accuracy: 0.0000e+00
# Epoch 8/20
# 16/16 [==============================] - 8s 493ms/step - loss: 0.8543 - accuracy: 0.5919 - val_loss: 1.3228 - val_accuracy: 0.0000e+00
# Epoch 9/20
# 16/16 [==============================] - 8s 518ms/step - loss: 0.8113 - accuracy: 0.6293 - val_loss: 1.3340 - val_accuracy: 0.0000e+00
# Epoch 10/20
# 16/16 [==============================] - 8s 468ms/step - loss: 0.7647 - accuracy: 0.6502 - val_loss: 1.3286 - val_accuracy: 0.0000e+00
# Epoch 11/20
# 16/16 [==============================] - 8s 485ms/step - loss: 0.7292 - accuracy: 0.6721 - val_loss: 1.3412 - val_accuracy: 0.0000e+00
# Epoch 12/20
# 16/16 [==============================] - 8s 502ms/step - loss: 0.6760 - accuracy: 0.6936 - val_loss: 1.3422 - val_accuracy: 0.0000e+00
# Epoch 13/20
# 16/16 [==============================] - 8s 483ms/step - loss: 0.6344 - accuracy: 0.7190 - val_loss: 1.3376 - val_accuracy: 0.0000e+00
# Epoch 14/20
# 16/16 [==============================] - 8s 498ms/step - loss: 0.5912 - accuracy: 0.7434 - val_loss: 1.3299 - val_accuracy: 0.0000e+00
# Epoch 15/20
# 16/16 [==============================] - 8s 469ms/step - loss: 0.5561 - accuracy: 0.7593 - val_loss: 1.3243 - val_accuracy: 0.0000e+00
# Epoch 16/20
# 16/16 [==============================] - 8s 475ms/step - loss: 0.5155 - accuracy: 0.7808 - val_loss: 1.3223 - val_accuracy: 0.0060
# Epoch 17/20
# 16/16 [==============================] - 8s 487ms/step - loss: 0.4715 - accuracy: 0.7932 - val_loss: 1.3419 - val_accuracy: 0.0100
# Epoch 18/20
# 16/16 [==============================] - 8s 479ms/step - loss: 0.4430 - accuracy: 0.8166 - val_loss: 1.3223 - val_accuracy: 0.0179
# Epoch 19/20
# 16/16 [==============================] - 8s 485ms/step - loss: 0.4119 - accuracy: 0.8326 - val_loss: 1.3340 - val_accuracy: 0.0438
# Epoch 20/20
# 16/16 [==============================] - 8s 483ms/step - loss: 0.3706 - accuracy: 0.8540 - val_loss: 1.3548 - val_accuracy: 0.0637

# %%
# Результаты обучения
plt.plot(historyRNN.history['accuracy'], 
         label='Доля верных ответов на обучающем наборе')
plt.plot(historyRNN.history['val_accuracy'], 
         label='Доля верных ответов на проверочном наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Доля верных ответов')
plt.legend()
plt.show()

# %%
# Дообучение модели
historyRNN = modelRNN.fit(xTrain, 
                          yTrain, 
                          epochs=40,
                          batch_size=128,
                          validation_split=0.2)
# Out:
# Epoch 1/40
# 16/16 [==============================] - 9s 541ms/step - loss: 0.3475 - accuracy: 0.8575 - val_loss: 1.3464 - val_accuracy: 0.0857
# Epoch 2/40
# 16/16 [==============================] - 8s 511ms/step - loss: 0.3297 - accuracy: 0.8764 - val_loss: 1.3696 - val_accuracy: 0.1116
# Epoch 3/40
# 16/16 [==============================] - 8s 517ms/step - loss: 0.3268 - accuracy: 0.8680 - val_loss: 1.3347 - val_accuracy: 0.1494
# Epoch 4/40
# 16/16 [==============================] - 8s 474ms/step - loss: 0.2879 - accuracy: 0.8884 - val_loss: 1.3568 - val_accuracy: 0.1713
# Epoch 5/40
# 16/16 [==============================] - 8s 514ms/step - loss: 0.2718 - accuracy: 0.8889 - val_loss: 1.4143 - val_accuracy: 0.1653
# Epoch 6/40
# 16/16 [==============================] - 8s 486ms/step - loss: 0.2613 - accuracy: 0.9008 - val_loss: 1.3438 - val_accuracy: 0.2251
# Epoch 7/40
# 16/16 [==============================] - 8s 515ms/step - loss: 0.2368 - accuracy: 0.9143 - val_loss: 1.3819 - val_accuracy: 0.2351
# Epoch 8/40
# 16/16 [==============================] - 8s 506ms/step - loss: 0.2387 - accuracy: 0.9003 - val_loss: 1.4289 - val_accuracy: 0.2351
# Epoch 9/40
# 16/16 [==============================] - 8s 514ms/step - loss: 0.2326 - accuracy: 0.9098 - val_loss: 1.4001 - val_accuracy: 0.2610
# Epoch 10/40
# 16/16 [==============================] - 8s 505ms/step - loss: 0.2110 - accuracy: 0.9193 - val_loss: 1.4871 - val_accuracy: 0.2331
# Epoch 11/40
# 16/16 [==============================] - 8s 518ms/step - loss: 0.1960 - accuracy: 0.9218 - val_loss: 1.5261 - val_accuracy: 0.2470
# Epoch 12/40
# 16/16 [==============================] - 7s 469ms/step - loss: 0.2085 - accuracy: 0.9158 - val_loss: 1.4217 - val_accuracy: 0.3127
# Epoch 13/40
# 16/16 [==============================] - 8s 486ms/step - loss: 0.1880 - accuracy: 0.9278 - val_loss: 1.5477 - val_accuracy: 0.2829
# Epoch 14/40
# 16/16 [==============================] - 8s 484ms/step - loss: 0.1860 - accuracy: 0.9283 - val_loss: 1.5625 - val_accuracy: 0.3008
# Epoch 15/40
# 16/16 [==============================] - 8s 485ms/step - loss: 0.1696 - accuracy: 0.9332 - val_loss: 1.5271 - val_accuracy: 0.3307
# Epoch 16/40
# 16/16 [==============================] - 8s 496ms/step - loss: 0.1573 - accuracy: 0.9407 - val_loss: 1.5889 - val_accuracy: 0.3287
# Epoch 17/40
# 16/16 [==============================] - 8s 506ms/step - loss: 0.1492 - accuracy: 0.9382 - val_loss: 1.6697 - val_accuracy: 0.3247
# Epoch 18/40
# 16/16 [==============================] - 8s 488ms/step - loss: 0.1456 - accuracy: 0.9467 - val_loss: 1.7567 - val_accuracy: 0.3187
# Epoch 19/40
# 16/16 [==============================] - 8s 487ms/step - loss: 0.1515 - accuracy: 0.9452 - val_loss: 1.7323 - val_accuracy: 0.3307
# Epoch 20/40
# 16/16 [==============================] - 8s 474ms/step - loss: 0.1505 - accuracy: 0.9427 - val_loss: 1.8150 - val_accuracy: 0.3247
# Epoch 21/40
# 16/16 [==============================] - 8s 487ms/step - loss: 0.1234 - accuracy: 0.9532 - val_loss: 1.9505 - val_accuracy: 0.3207
# Epoch 22/40
# 16/16 [==============================] - 8s 534ms/step - loss: 0.1202 - accuracy: 0.9562 - val_loss: 1.8837 - val_accuracy: 0.3645
# Epoch 23/40
# 16/16 [==============================] - 8s 491ms/step - loss: 0.1373 - accuracy: 0.9412 - val_loss: 1.8953 - val_accuracy: 0.3745
# Epoch 24/40
# 16/16 [==============================] - 8s 492ms/step - loss: 0.1306 - accuracy: 0.9487 - val_loss: 1.9290 - val_accuracy: 0.3845
# Epoch 25/40
# 16/16 [==============================] - 8s 488ms/step - loss: 0.1182 - accuracy: 0.9527 - val_loss: 2.0728 - val_accuracy: 0.3685
# Epoch 26/40
# 16/16 [==============================] - 8s 498ms/step - loss: 0.1135 - accuracy: 0.9581 - val_loss: 1.9841 - val_accuracy: 0.3845
# Epoch 27/40
# 16/16 [==============================] - 8s 479ms/step - loss: 0.1114 - accuracy: 0.9611 - val_loss: 1.9181 - val_accuracy: 0.4024
# Epoch 28/40
# 16/16 [==============================] - 8s 507ms/step - loss: 0.1137 - accuracy: 0.9562 - val_loss: 2.0677 - val_accuracy: 0.3865
# Epoch 29/40
# 16/16 [==============================] - 8s 492ms/step - loss: 0.1247 - accuracy: 0.9537 - val_loss: 2.0916 - val_accuracy: 0.3865
# Epoch 30/40
# 16/16 [==============================] - 8s 493ms/step - loss: 0.1098 - accuracy: 0.9626 - val_loss: 2.0894 - val_accuracy: 0.3865
# Epoch 31/40
# 16/16 [==============================] - 8s 493ms/step - loss: 0.1006 - accuracy: 0.9671 - val_loss: 2.1377 - val_accuracy: 0.3884
# Epoch 32/40
# 16/16 [==============================] - 8s 477ms/step - loss: 0.1103 - accuracy: 0.9621 - val_loss: 2.1278 - val_accuracy: 0.4502
# Epoch 33/40
# 16/16 [==============================] - 8s 483ms/step - loss: 0.1020 - accuracy: 0.9576 - val_loss: 2.0734 - val_accuracy: 0.4283
# Epoch 34/40
# 16/16 [==============================] - 8s 484ms/step - loss: 0.0881 - accuracy: 0.9681 - val_loss: 2.0914 - val_accuracy: 0.4343
# Epoch 35/40
# 16/16 [==============================] - 8s 496ms/step - loss: 0.0916 - accuracy: 0.9681 - val_loss: 2.0674 - val_accuracy: 0.4402
# Epoch 36/40
# 16/16 [==============================] - 8s 469ms/step - loss: 0.0838 - accuracy: 0.9706 - val_loss: 2.0247 - val_accuracy: 0.4562
# Epoch 37/40
# 16/16 [==============================] - 9s 538ms/step - loss: 0.1031 - accuracy: 0.9651 - val_loss: 2.0604 - val_accuracy: 0.4622
# Epoch 38/40
# 16/16 [==============================] - 8s 487ms/step - loss: 0.0783 - accuracy: 0.9746 - val_loss: 2.1845 - val_accuracy: 0.4283
# Epoch 39/40
# 16/16 [==============================] - 7s 461ms/step - loss: 0.0818 - accuracy: 0.9716 - val_loss: 2.1032 - val_accuracy: 0.4462
# Epoch 40/40
# 16/16 [==============================] - 8s 524ms/step - loss: 0.0787 - accuracy: 0.9701 - val_loss: 2.1513 - val_accuracy: 0.4402

# %%
# Результаты обучения
plt.plot(historyRNN.history['accuracy'], 
         label='Доля верных ответов на обучающем наборе')
plt.plot(historyRNN.history['val_accuracy'], 
         label='Доля верных ответов на проверочном наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Доля верных ответов')
plt.legend()
plt.show()

# %% [markdown]
# Нейросеть для классификации текстов на базе LSTM

# %%
modelLSTM = Sequential()

modelLSTM.add(Embedding(numWords, 100, input_length=xLen))
modelLSTM.add(SpatialDropout1D(0.2))
modelLSTM.add(BatchNormalization())

modelLSTM.add(LSTM(10))
modelLSTM.add(Dense(3, activation='softmax'))

modelLSTM.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

modelLSTM.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 300, 100)          2000000
#
#  spatial_dropout1d_2 (Spatia  (None, 300, 100)         0
#  lDropout1D)
#
#  batch_normalization_2 (Batc  (None, 300, 100)         400
#  hNormalization)
#
#  lstm_1 (LSTM)               (None, 10)                4440
#
#  dense_2 (Dense)             (None, 3)                 33
#
# =================================================================
# Total params: 2,004,873
# Trainable params: 2,004,673
# Non-trainable params: 200
# _________________________________________________________________

# %%
# Обучаем сеть
historyLSTM = modelLSTM.fit(xTrain, 
                            yTrain, 
                            epochs=100,
                            batch_size=128,
                            validation_split=0.2)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 3s 60ms/step - loss: 1.0467 - accuracy: 0.4519 - val_loss: 1.3082 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.7924 - accuracy: 0.7489 - val_loss: 1.3837 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.5700 - accuracy: 0.9008 - val_loss: 1.4711 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.3579 - accuracy: 0.9691 - val_loss: 1.6721 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 16/16 [==============================] - 0s 22ms/step - loss: 0.1988 - accuracy: 0.9945 - val_loss: 1.9488 - val_accuracy: 0.0279
# Epoch 6/100
# 16/16 [==============================] - 0s 22ms/step - loss: 0.1085 - accuracy: 1.0000 - val_loss: 1.7335 - val_accuracy: 0.3347
# Epoch 7/100
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0665 - accuracy: 1.0000 - val_loss: 1.9792 - val_accuracy: 0.3705
# Epoch 8/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0464 - accuracy: 1.0000 - val_loss: 2.7460 - val_accuracy: 0.1673
# Epoch 9/100
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0354 - accuracy: 1.0000 - val_loss: 2.7603 - val_accuracy: 0.2052
# Epoch 10/100
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0287 - accuracy: 1.0000 - val_loss: 2.7392 - val_accuracy: 0.2390
# Epoch 11/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0240 - accuracy: 1.0000 - val_loss: 2.6814 - val_accuracy: 0.2849
# Epoch 12/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0206 - accuracy: 1.0000 - val_loss: 2.6758 - val_accuracy: 0.3008
# Epoch 13/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 2.5776 - val_accuracy: 0.3406
# Epoch 14/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 2.4383 - val_accuracy: 0.3904
# Epoch 15/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 2.3213 - val_accuracy: 0.4263
# Epoch 16/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 2.3239 - val_accuracy: 0.4303
# Epoch 17/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 2.4330 - val_accuracy: 0.4084
# Epoch 18/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 2.4666 - val_accuracy: 0.4044
# Epoch 19/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 2.4521 - val_accuracy: 0.4084
# Epoch 20/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 2.3817 - val_accuracy: 0.4163
# Epoch 21/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 2.3066 - val_accuracy: 0.4283
# Epoch 22/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 2.2216 - val_accuracy: 0.4422
# Epoch 23/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 2.0763 - val_accuracy: 0.4681
# Epoch 24/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 1.8737 - val_accuracy: 0.5100
# Epoch 25/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 1.6498 - val_accuracy: 0.5657
# Epoch 26/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0075 - accuracy: 0.9995 - val_loss: 0.8170 - val_accuracy: 0.7709
# Epoch 27/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0077 - accuracy: 0.9995 - val_loss: 1.4519 - val_accuracy: 0.5518
# Epoch 28/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0102 - accuracy: 0.9985 - val_loss: 0.7715 - val_accuracy: 0.7171
# Epoch 29/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0079 - accuracy: 0.9995 - val_loss: 0.8084 - val_accuracy: 0.7072
# Epoch 30/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.8905 - val_accuracy: 0.6773
# Epoch 31/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.8693 - val_accuracy: 0.6833
# Epoch 32/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.8475 - val_accuracy: 0.6912
# Epoch 33/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.8222 - val_accuracy: 0.6972
# Epoch 34/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.8072 - val_accuracy: 0.7052
# Epoch 35/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.7980 - val_accuracy: 0.7032
# Epoch 36/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.7928 - val_accuracy: 0.6932
# Epoch 37/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.7912 - val_accuracy: 0.6952
# Epoch 38/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.7929 - val_accuracy: 0.6892
# Epoch 39/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.7964 - val_accuracy: 0.6912
# Epoch 40/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.7998 - val_accuracy: 0.6753
# Epoch 41/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.8043 - val_accuracy: 0.6733
# Epoch 42/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.8071 - val_accuracy: 0.6773
# Epoch 43/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.8109 - val_accuracy: 0.6733
# Epoch 44/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.8141 - val_accuracy: 0.6733
# Epoch 45/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.8168 - val_accuracy: 0.6673
# Epoch 46/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.8172 - val_accuracy: 0.6673
# Epoch 47/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.8194 - val_accuracy: 0.6653
# Epoch 48/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.8218 - val_accuracy: 0.6633
# Epoch 49/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.8240 - val_accuracy: 0.6633
# Epoch 50/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.8270 - val_accuracy: 0.6614
# Epoch 51/100
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.8218 - val_accuracy: 0.6614
# Epoch 52/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.8243 - val_accuracy: 0.6594
# Epoch 53/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.8260 - val_accuracy: 0.6574
# Epoch 54/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.8277 - val_accuracy: 0.6534
# Epoch 55/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.8302 - val_accuracy: 0.6514
# Epoch 56/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.8314 - val_accuracy: 0.6534
# Epoch 57/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.8327 - val_accuracy: 0.6534
# Epoch 58/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.8330 - val_accuracy: 0.6534
# Epoch 59/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.8344 - val_accuracy: 0.6534
# Epoch 60/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.8365 - val_accuracy: 0.6514
# Epoch 61/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.8389 - val_accuracy: 0.6514
# Epoch 62/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.8397 - val_accuracy: 0.6514
# Epoch 63/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.8411 - val_accuracy: 0.6514
# Epoch 64/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.8425 - val_accuracy: 0.6514
# Epoch 65/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.8442 - val_accuracy: 0.6514
# Epoch 66/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.8466 - val_accuracy: 0.6494
# Epoch 67/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.8485 - val_accuracy: 0.6494
# Epoch 68/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.8502 - val_accuracy: 0.6494
# Epoch 69/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.8518 - val_accuracy: 0.6514
# Epoch 70/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.8538 - val_accuracy: 0.6514
# Epoch 71/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.8547 - val_accuracy: 0.6514
# Epoch 72/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.8558 - val_accuracy: 0.6514
# Epoch 73/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.8577 - val_accuracy: 0.6514
# Epoch 74/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.8597 - val_accuracy: 0.6494
# Epoch 75/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.8613 - val_accuracy: 0.6494
# Epoch 76/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.8629 - val_accuracy: 0.6494
# Epoch 77/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.8642 - val_accuracy: 0.6514
# Epoch 78/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.8654 - val_accuracy: 0.6494
# Epoch 79/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.8661 - val_accuracy: 0.6494
# Epoch 80/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.8673 - val_accuracy: 0.6494
# Epoch 81/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.8684 - val_accuracy: 0.6494
# Epoch 82/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.8700 - val_accuracy: 0.6494
# Epoch 83/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.8716 - val_accuracy: 0.6494
# Epoch 84/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.8733 - val_accuracy: 0.6494
# Epoch 85/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.8748 - val_accuracy: 0.6494
# Epoch 86/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.8765 - val_accuracy: 0.6474
# Epoch 87/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.8776 - val_accuracy: 0.6474
# Epoch 88/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.8789 - val_accuracy: 0.6474
# Epoch 89/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.8801 - val_accuracy: 0.6474
# Epoch 90/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.8811 - val_accuracy: 0.6474
# Epoch 91/100
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.8825 - val_accuracy: 0.6474
# Epoch 92/100
# 16/16 [==============================] - 0s 24ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.8833 - val_accuracy: 0.6474
# Epoch 93/100
# 16/16 [==============================] - 0s 23ms/step - loss: 9.8524e-04 - accuracy: 1.0000 - val_loss: 0.8846 - val_accuracy: 0.6474
# Epoch 94/100
# 16/16 [==============================] - 0s 24ms/step - loss: 9.6770e-04 - accuracy: 1.0000 - val_loss: 0.8858 - val_accuracy: 0.6474
# Epoch 95/100
# 16/16 [==============================] - 0s 23ms/step - loss: 9.5115e-04 - accuracy: 1.0000 - val_loss: 0.8876 - val_accuracy: 0.6474
# Epoch 96/100
# 16/16 [==============================] - 0s 24ms/step - loss: 9.3414e-04 - accuracy: 1.0000 - val_loss: 0.8886 - val_accuracy: 0.6474
# Epoch 97/100
# 16/16 [==============================] - 0s 24ms/step - loss: 9.1824e-04 - accuracy: 1.0000 - val_loss: 0.8896 - val_accuracy: 0.6474
# Epoch 98/100
# 16/16 [==============================] - 0s 23ms/step - loss: 9.0404e-04 - accuracy: 1.0000 - val_loss: 0.8907 - val_accuracy: 0.6474
# Epoch 99/100
# 16/16 [==============================] - 0s 24ms/step - loss: 8.8822e-04 - accuracy: 1.0000 - val_loss: 0.8920 - val_accuracy: 0.6474
# Epoch 100/100
# 16/16 [==============================] - 0s 24ms/step - loss: 8.7258e-04 - accuracy: 1.0000 - val_loss: 0.8939 - val_accuracy: 0.6474

# %%
# Результаты с шагом и рамкой = 500
# Epoch 100/100
# 10/10 [==============================] - 1s 87ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.2687 - val_accuracy: 0.4371
# Они хуже, чем текущий вариант с шагом и рамкой = 300

# Результаты обучения
plt.plot(historyLSTM.history['accuracy'], 
         label='Доля верных ответов на обучающем наборе')
plt.plot(historyLSTM.history['val_accuracy'], 
         label='Доля верных ответов на проверочном наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Доля верных ответов')
plt.legend()
plt.show()

# %% [markdown]
# Проверяем работу обученной нейросети LSTM

# %%
# Проверяем точность на тестовой выборке

rightAnswer = [0,0,0]
totalAnswer = [0,0,0]

# Получаем результаты распознавания для каждого класса
currPred = modelLSTM.predict(xTest)
# Определяем номер распознанного класса для каждохо вектора
currOut = np.argmax(currPred, axis=1)
# Определяем правильный класс для каждохо вектора
yOut = np.argmax(yTest, axis=1)

print(currPred.shape)
print(currOut.shape)
print(yOut.shape)
print()


# Считаем сколько ответов всего и сколько из них правильных
for i in range(len(yOut)):
  predictA = currOut[i]
  rightA   = yOut[i]

  totalAnswer[rightA] += 1
  if predictA == rightA:
    rightAnswer[rightA] += 1

# Подсчитываем точность классификации
print("Точность распознавания текстов новостей")
for i in range(labelsNum):
  print("{:12s}: {:3d} из {:3d} - {:3.2f}%".format(labels[i], rightAnswer[i], totalAnswer[i], (rightAnswer[i]/totalAnswer[i]*100)))
# Out:
# (257, 3)
# (257,)
# (257,)
#
# Точность распознавания текстов новостей
# Политика    :  68 из  89 - 76.40%
# Спорт       :  58 из  81 - 71.60%
# Технологии  :  51 из  87 - 58.62%

# %% [markdown]
# #Дополнительные тесты

# %% [markdown]
# Нейросеть для классификации текстов на базе двух слоев LSTM

# %%
modelLSTM2 = Sequential()

modelLSTM2.add(Embedding(numWords, 100, input_length=xLen))
modelLSTM2.add(SpatialDropout1D(0.2))
modelLSTM2.add(BatchNormalization())

modelLSTM2.add(LSTM(10, return_sequences=1))
modelLSTM2.add(LSTM(5))
modelLSTM2.add(Dense(3, activation='softmax'))

modelLSTM2.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

modelLSTM2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 300, 100)          2000000
#
#  spatial_dropout1d_3 (Spatia  (None, 300, 100)         0
#  lDropout1D)
#
#  batch_normalization_3 (Batc  (None, 300, 100)         400
#  hNormalization)
#
#  lstm_2 (LSTM)               (None, 300, 10)           4440
#
#  lstm_3 (LSTM)               (None, 5)                 320
#
#  dense_3 (Dense)             (None, 3)                 18
#
# =================================================================
# Total params: 2,005,178
# Trainable params: 2,004,978
# Non-trainable params: 200
# _________________________________________________________________

# %%
# Обучаем сеть
historyLSTM2 = modelLSTM2.fit(xTrain, 
                              yTrain, 
                              epochs=60,
                              batch_size=128,
                              validation_split=0.2)
# Out:
# Epoch 1/60
# 16/16 [==============================] - 1s 44ms/step - loss: 0.0382 - accuracy: 1.0000 - val_loss: 3.7998 - val_accuracy: 0.0080
# Epoch 2/60
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0359 - accuracy: 1.0000 - val_loss: 3.8157 - val_accuracy: 0.0139
# Epoch 3/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0339 - accuracy: 1.0000 - val_loss: 3.7404 - val_accuracy: 0.0259
# Epoch 4/60
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0321 - accuracy: 1.0000 - val_loss: 3.5446 - val_accuracy: 0.0438
# Epoch 5/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0304 - accuracy: 1.0000 - val_loss: 3.2528 - val_accuracy: 0.0817
# Epoch 6/60
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0298 - accuracy: 0.9995 - val_loss: 1.7578 - val_accuracy: 0.4422
# Epoch 7/60
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0278 - accuracy: 1.0000 - val_loss: 1.7793 - val_accuracy: 0.4622
# Epoch 8/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0264 - accuracy: 1.0000 - val_loss: 1.4909 - val_accuracy: 0.5319
# Epoch 9/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0252 - accuracy: 1.0000 - val_loss: 1.0556 - val_accuracy: 0.6673
# Epoch 10/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0241 - accuracy: 1.0000 - val_loss: 0.8614 - val_accuracy: 0.7291
# Epoch 11/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0231 - accuracy: 1.0000 - val_loss: 0.7178 - val_accuracy: 0.7669
# Epoch 12/60
# 16/16 [==============================] - 1s 42ms/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.6149 - val_accuracy: 0.8008
# Epoch 13/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.5524 - val_accuracy: 0.8207
# Epoch 14/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0205 - accuracy: 1.0000 - val_loss: 0.5093 - val_accuracy: 0.8367
# Epoch 15/60
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.4668 - val_accuracy: 0.8486
# Epoch 16/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0218 - accuracy: 0.9995 - val_loss: 0.6202 - val_accuracy: 0.7948
# Epoch 17/60
# 16/16 [==============================] - 1s 42ms/step - loss: 0.0214 - accuracy: 0.9995 - val_loss: 0.3959 - val_accuracy: 0.8705
# Epoch 18/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0191 - accuracy: 0.9995 - val_loss: 0.3933 - val_accuracy: 0.8665
# Epoch 19/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0201 - accuracy: 0.9995 - val_loss: 0.4030 - val_accuracy: 0.8685
# Epoch 20/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.4002 - val_accuracy: 0.8705
# Epoch 21/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.4030 - val_accuracy: 0.8645
# Epoch 22/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.4036 - val_accuracy: 0.8645
# Epoch 23/60
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.4046 - val_accuracy: 0.8606
# Epoch 24/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.4061 - val_accuracy: 0.8606
# Epoch 25/60
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.4081 - val_accuracy: 0.8606
# Epoch 26/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.4108 - val_accuracy: 0.8586
# Epoch 27/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.4144 - val_accuracy: 0.8586
# Epoch 28/60
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.4166 - val_accuracy: 0.8586
# Epoch 29/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.4192 - val_accuracy: 0.8586
# Epoch 30/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.4215 - val_accuracy: 0.8566
# Epoch 31/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.4224 - val_accuracy: 0.8546
# Epoch 32/60
# 16/16 [==============================] - 1s 42ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.4243 - val_accuracy: 0.8546
# Epoch 33/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.4261 - val_accuracy: 0.8546
# Epoch 34/60
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.4268 - val_accuracy: 0.8526
# Epoch 35/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.4278 - val_accuracy: 0.8526
# Epoch 36/60
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.4298 - val_accuracy: 0.8526
# Epoch 37/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.4314 - val_accuracy: 0.8506
# Epoch 38/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.4328 - val_accuracy: 0.8506
# Epoch 39/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.4346 - val_accuracy: 0.8486
# Epoch 40/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.4353 - val_accuracy: 0.8486
# Epoch 41/60
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.4363 - val_accuracy: 0.8486
# Epoch 42/60
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.4383 - val_accuracy: 0.8486
# Epoch 43/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.4941 - val_accuracy: 0.8327
# Epoch 44/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.5103 - val_accuracy: 0.8307
# Epoch 45/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.5144 - val_accuracy: 0.8287
# Epoch 46/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.5098 - val_accuracy: 0.8287
# Epoch 47/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.5091 - val_accuracy: 0.8307
# Epoch 48/60
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.5104 - val_accuracy: 0.8327
# Epoch 49/60
# 16/16 [==============================] - 1s 39ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.5053 - val_accuracy: 0.8426
# Epoch 50/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0085 - accuracy: 0.9995 - val_loss: 0.5072 - val_accuracy: 0.8327
# Epoch 51/60
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0213 - accuracy: 0.9970 - val_loss: 0.4560 - val_accuracy: 0.8566
# Epoch 52/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0155 - accuracy: 0.9980 - val_loss: 0.3995 - val_accuracy: 0.8725
# Epoch 53/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0133 - accuracy: 0.9990 - val_loss: 0.4920 - val_accuracy: 0.8267
# Epoch 54/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.5189 - val_accuracy: 0.8187
# Epoch 55/60
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.5004 - val_accuracy: 0.8307
# Epoch 56/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.4892 - val_accuracy: 0.8347
# Epoch 57/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.4822 - val_accuracy: 0.8367
# Epoch 58/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.4760 - val_accuracy: 0.8386
# Epoch 59/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.4715 - val_accuracy: 0.8446
# Epoch 60/60
# 16/16 [==============================] - 1s 41ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.4978 - val_accuracy: 0.8386

# %%
# Результаты обучения
plt.plot(historyLSTM2.history['accuracy'], 
         label='Доля верных ответов на обучающем наборе')
plt.plot(historyLSTM2.history['val_accuracy'], 
         label='Доля верных ответов на проверочном наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Доля верных ответов')
plt.legend()
plt.show()

# %% [markdown]
# Проверяем работу обученной нейросети с двумя слоями LSTM

# %%
# Проверяем точность на тестовой выборке

rightAnswer = [0,0,0]
totalAnswer = [0,0,0]

# Получаем результаты распознавания для каждого класса
currPred = modelLSTM2.predict(xTest)
# Определяем номер распознанного класса для каждохо вектора
currOut = np.argmax(currPred, axis=1)
# Определяем правильный класс для каждохо вектора
yOut = np.argmax(yTest, axis=1)

print(currPred.shape)
print(currOut.shape)
print(yOut.shape)
print()


# Считаем сколько ответов всего и сколько из них правильных
for i in range(len(yOut)):
  predictA = currOut[i]
  rightA   = yOut[i]

  totalAnswer[rightA] += 1
  if predictA == rightA:
    rightAnswer[rightA] += 1

# Подсчитываем точность классификации
print("Точность распознавания текстов новостей")
for i in range(labelsNum):
  print("{:12s}: {:3d} из {:3d} - {:3.2f}%".format(labels[i], rightAnswer[i], totalAnswer[i], (rightAnswer[i]/totalAnswer[i]*100)))
# Out:
# (257, 3)
# (257,)
# (257,)
#
# Точность распознавания текстов новостей
# Политика    :  83 из  89 - 93.26%
# Спорт       :  72 из  81 - 88.89%
# Технологии  :  64 из  87 - 73.56%
