# %%
# Устанавливаем библиотеку для манипуляции над аудио файлами
# !pip install pydub

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pydub import AudioSegment
import numpy as np
import array

# Так как выполняю работу на лок. сервере Jupyter Notebook файлы придётся загружать иначе
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
# Файл речи # 14 мин 12 сек = 852 секунды
audio = AudioSegment.from_mp3("G:\College_Courses\Machine-learning-projects\my_speech.mp3")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# g:\College_Courses\Machine-learning-projects\2_my_speech_dataset.ipynb Cell 4 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/g%3A/College_Courses/Machine-learning-projects/2_my_speech_dataset.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> # Файл речи # 14 мин 12 сек = 852 секунды
# ----> <a href='vscode-notebook-cell:/g%3A/College_Courses/Machine-learning-projects/2_my_speech_dataset.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> audio = AudioSegment.from_mp3("G:\College_Courses\Machine-learning-projects\my_speech.mp3")
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pydub\audio_segment.py:796, in AudioSegment.from_mp3(cls, file, parameters)
#     794 @classmethod
#     795 def from_mp3(cls, file, parameters=None):
# --> 796     return cls.from_file(file, 'mp3', parameters=parameters)
#
# ...

# %%
audio

# %%
# Файл с шумом дождя .mp3 # 1 мин 32 сек = 92 секунды
noise_rain = AudioSegment.from_mp3("/content/drive/MyDrive/Colab Notebooks/Machine_learning/Term5/Homeworks/hw4_audio/dojd_v_avtomobile.mp3")

# %%
noise_rain
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
# Запустив два аудиофайла выше одновременно понимаю, что шум слишком громкий.
# Его необходимо сделать тише

# Подавление шума дождя на 5 дб
noise_rain -= 5

# %%
# Шум дождя по длине не совпадает с файлом речи
# Нужно его удлинить
# 852 / 92 = 9.26. Буду умножать на 10, чтобы точно покрыть шумом всю запись
noise_rain *= 10

noise_rain

# %%
# Теперь можно наложить шум на речь

# Голос + 10 секунд шума дождя
noise_rain_audio = audio.overlay(noise_rain) # Наложение шума на речь
noise_rain_audio
